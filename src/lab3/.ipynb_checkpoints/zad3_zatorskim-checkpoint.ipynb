# %%
import numpy as np
from matplotlib import pyplot as plt
import imageio
from PIL import Image

# %% [markdown]
# # Ex. 1) Przekształcenie sfery w elipsoidę

# %% [markdown]
# ### 1.
# Korzystając z równania parametrycznego:
#
# $ \textbf{v} = \begin{bmatrix}cos(s)sin(t) \\ sin(s)sin(t) \\ cos(t)\end{bmatrix}  $
#
# Narysujemy sferę jednostkową w 3D dla:
#
# $s \in [0, 2\pi], t \in [0, \pi]$

# %% [markdown]
# Zdefiniujemy w pogramie dane zadane nam w poleceniu

# %%
s_range = [0, 2*np.pi]
t_range = [0, np.pi]
v = [lambda s, t : np.cos(s)*np.sin(t),
     lambda s, t : np.sin(s)*np.sin(t),
     lambda s, t : np.cos(t)]

# %% [markdown]
# Zdefiniujemy funkcję, która przyjmując przedział $s$, $t$ oraz wektor funkcji $v$, narysuje nam wykres oraz zwróci zbiór punktów należących do sfery.

# %%
def plot_3d(x, y, z):
    fig = plt.figure()
    ax = plt.axes(projection="3d")
    ax.plot3D(x, y, z)
    plt.show()


def draw_3d_sphere(s_range, t_range, v, n = 40):
    s = np.linspace(s_range[0], s_range[1], n)
    t = np.linspace(t_range[0], t_range[1], n)
    
    S, T = np.meshgrid(s, t)
    
    x = v[0](S, T).flatten()
    y = v[1](S, T).flatten()
    z = v[2](S, T).flatten()
    
    plot_3d(x,y,z)
    
    return x, y, z

x, y, z = draw_3d_sphere(s_range, t_range, v)

# %% [markdown]
# ***
#
# *Jak widać w wyniku dostaliśmy sferę o promieniu $R = 1$ i środku w punkcie $(0,0,0)$*

# %% [markdown]
# ---
# ### 2.
#
# Następnie wygenerujemy 3 różne macierze $\textbf{A_1, A_2, A_3, } (\textbf{A_i} \in \mathbb{R}^{3x3})$

# %%
A1 = np.random.rand(3, 3)
A2 = np.random.rand(3, 3)
A3 = np.random.rand(3, 3)

# %% [markdown]
# Za ich pomocą przekształcimy sferę w elipsoidę i przedstawimy wizualizację uzyskanego wyniku na wykresie.

# %%
S = np.row_stack([x, y, z])

E_1 = A1 @ S
E_2 = A2 @ S
E_3 = A3 @ S

plot_3d(E_1[0], E_1[1], E_1[2])
plot_3d(E_2[0], E_2[1], E_2[2])
plot_3d(E_3[0], E_3[1], E_3[2])

# %% [markdown]
# ---
# ### 3.
#
# Teraz dokonamy rozkładu wartości osobliwych SVD w każdej macierzy <strong>$A_i$</strong>.\
# Użyjemy w tym celu funkcji `linalg.svd` z biblioteki `numpy`

# %%
U1, sigma1, V1 = np.linalg.svd(A_1)
U2, sigma2, V2 = np.linalg.svd(A_2)
U3, sigma3, V3 = np.linalg.svd(A_3)

# %% [markdown]
# Teraz na wykresie elipsoidy odpowiadającej każdej macierzy dodamy wizualizację jej półosi wyznaczonych za pomocą SVD

# %% [markdown]
# Przygotujemy zmienne na wyrysowanie półosi:

# %%
x_start, y_start, z_start = [[0] * 3] * 3
x_end = [0] * 3
y_end = [0] * 3
z_end = [0] * 3

# %% [markdown]
# ### $A_1$

# %%
for i, s1 in enumerate(np.diag(sigma1)):
    a = np.dot(U1, s1)
    x_end[i] = a[0]
    y_end[i] = a[1]
    z_end[i] = a[2]
quiver1 = [x_start, y_start, z_start, x_end, y_end, z_end]


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z)
ax.scatter(E_1[0], E_1[1], E_1[2], color='red')
ax.quiver(x_start, y_start, z_start, x_end, y_end, z_end, color='black')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)
plt.show()

# %% [markdown]
# ### $A_2$

# %%
for i, s2 in enumerate(np.diag(sigma2)):
    a = np.dot(U2, s2)
    x_end[i] = a[0]
    y_end[i] = a[1]
    z_end[i] = a[2]
quiver2 = [x_start, y_start, z_start, x_end, y_end, z_end]


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z)
ax.scatter(E_2[0], E_2[1], E_2[2], color='red')
ax.quiver(x_start, y_start, z_start, x_end, y_end, z_end, color='black')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)
plt.show()

# %% [markdown]
# ### $A_3$

# %%
for i, s3 in enumerate(np.diag(sigma3)):
    a = np.dot(U3, s3)
    x_end[i] = a[0]
    y_end[i] = a[1]
    z_end[i] = a[2]
quiver2 = [x_start, y_start, z_start, x_end, y_end, z_end]


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z)
ax.scatter(E_3[0], E_3[1], E_3[2], color='red')
ax.quiver(x_start, y_start, z_start, x_end, y_end, z_end, color='black')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)
plt.show()

# %% [markdown]
# ---
# ### 4.
# Znajdziemy taką macierz <strong>$A_i$</strong>, aby stosunek jej największej i najmniejszej wartości osobliwej był większy od 100.

# %%
A_4 = np.random.rand(3, 3)
U, sigma_4, V = np.linalg.svd(A_4)
# ponieważ wartości osobliwe są posortowane malejąco
while sigma_4[0] / sigma_4[-1] < 100:
    A_4 = np.random.rand(3, 3)
    U, sigma_4, V = np.linalg.svd(A_4)
    
A_4
# Out:
# array([[0.92458889, 0.56223001, 0.28332396],
#        [0.54817791, 0.36017676, 0.47067057],
#        [0.47566025, 0.30402474, 0.92293489]])

# %% [markdown]
# Teraz narysujemy elipsoidę dla znalezionej macierzy

# %%
E_4 = A_4 @ S
plot_3d(E_4[0], E_4[1], E_4[2])

# %% [markdown]
# ---
# ### 5.
# Dla wybranej macierzy $A_i$ mamy teraz przedstawić wizualizację $SV_i^T$, $S\Sigma_iV_i^T$ oraz $SU_i\Sigma_iV_i^T$
#
# gdzie
#
# $A_i = U_i\Sigma_iV_i^T$
# oraz
# $S$ <- sfera z punktu 1.

# %% [markdown]
# Naszą wybraną macierzą będzie $A_1$

# %%
# Make SVD
U, sigma, V = np.linalg.svd(A_1)

# %% [markdown]
# $SV_i^T$

# %%
elipsoid = V.T @ S

plot_3d(elipsoid[0], elipsoid[1], elipsoid[2])

# %% [markdown]
# $S\Sigma_iV_i^T$

# %%
elipsoid = S.T * sigma @ V
elipsoid = elipsoid.T

plot_3d(elipsoid[0], elipsoid[1], elipsoid[2])

# %% [markdown]
# $SU_i\Sigma_iV_i^T$

# %%
elipsoid = S.T @ U * sigma @ V
SUSigmaV_T = elipsoid.T

plot_3d(elipsoid[0], elipsoid[1], elipsoid[2])

# %% [markdown]
# # Ex. 1) Kompresja obrazu

# %% [markdown]
# ### 1.
# Przygotujemy zdjęcie 512 x 512 pikseli

# %% [markdown]
# <img src="image.png">

# %% [markdown]
# ---
# ### 1.
# Wczytamy obraz do programu i następnie obliczymy SVD macierzy pikseli <b>$I$</b>

# %%
matrix = np.asarray(imageio.imread('image.png'))
U, S, V = np.linalg.svd(matrix)

# %% [markdown]
# Dla $k \in [32, 64, 96, \dots, 512]$ pierwszy wartości osobliwych dokonamy przybliżenia tej macierzy za pomocą `low rank approximation`. W ten sposób uzyskamy kompresję obrazu wyjściowego.

# %%
def low_rank_approximation(U, S, V, k):
    Uk = U[:, :k]
    Sk = S[:k]
    Vk = V[:k, :]
    result = Uk * Sk * Vk
    return result


def get_quality(matrix, approx_matrix):
    diff_matrix = np.subtract(matrix, approx_matrix)
    quality = np.linalg.norm(diff_matrix)
    return quality


ks = []
qualities = []

images = []

for k in range(32, 513, 32):
    approx_matrix = low_rank_approximation(U, S, V, k)
    ks.append(k)
    quality = get_quality(matrix, approx_matrix)
    qualities.append(quality)
    compressed_image = Image.fromarray(approx_matrix)
    compressed_image = compressed_image.convert("RGB")
    images.append(compressed_image)
    filename = "lenna_image_" + str(k) + ".jpg"
    compressed_image.save(filename)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-fbc4aa3d3ddf> in <module>
#      19
#      20 for k in range(512, 31, -32):
# ---> 21     approx_matrix = low_rank_approximation(U, S, V, k)
#      22     ks.append(k)
#      23     quality = get_quality(matrix, approx_matrix)
#
# <ipython-input-206-fbc4aa3d3ddf> in low_rank_approximation(U, S, V, k)
#       3     Sk = S[:k]
#       4     Vk = V[:k, :]
# ----> 5     result = Uk * Sk * Vk
#       6     return result
#       7
#
# ValueError: operands could not be broadcast together with shapes (512,512,512) (512,3)

# %%
plt.plot(ks, qualities)
plt.show()

images[0].save("lennas.gif", save_all=True, append_images=images[1:], duration=256, loop=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-c4a3771fbe4f> in <module>
#      20
#      21 for k in range(32, 512, 32):
# ---> 22     approx_matrix = low_rank_approximation(matrix, k)
#      23     ks.append(k)
#      24     quality = get_quality(matrix, approx_matrix)
#
# <ipython-input-198-c4a3771fbe4f> in low_rank_approximation(matrix, k)
#       1 def low_rank_approximation(matrix, k):
#       2     U, S, V = np.linalg.svd(matrix)
# ----> 3     Uk = np.matrix(U[:, :k])
#       4     Sk = np.diag(S[:k])
#       5     Vk = np.matrix(V[:k, :])
#
# ~/projects/mownit/venv/lib/python3.6/site-packages/numpy/matrixlib/defmatrix.py in __new__(subtype, data, dtype, copy)
#     135             else:
#     136                 intype = N.dtype(dtype)
# --> 137             new = data.view(subtype)
#     138             if intype != data.dtype:
#     139                 return new.astype(intype)
#
# ~/projects/mownit/venv/lib/python3.6/site-packages/numpy/matrixlib/defmatrix.py in __array_finalize__(self, obj)
#     180                 return
#     181             elif (ndim > 2):
# --> 182                 raise ValueError("shape too large to be a matrix.")
#     183         else:
#     184             newshape = self.shape
#
# ValueError: shape too large to be a matrix.
