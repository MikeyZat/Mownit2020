# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import imageio
from PIL import Image

# %% [markdown]
# # Ex. 1) Przekształcenie sfery w elipsoidę

# %% [markdown]
# ### 1.
# Korzystając z równania parametrycznego:
#
# $ \textbf{v} = \begin{bmatrix}cos(s)sin(t) \\ sin(s)sin(t) \\ cos(t)\end{bmatrix}  $
#
# Narysujemy sferę jednostkową w 3D dla:
#
# $s \in [0, 2\pi], t \in [0, \pi]$

# %% [markdown]
# Zdefiniujemy w pogramie dane zadane nam w poleceniu

# %%
s_range = [0, 2*np.pi]
t_range = [0, np.pi]
v = [lambda s, t : np.cos(s)*np.sin(t),
     lambda s, t : np.sin(s)*np.sin(t),
     lambda s, t : np.cos(t)]

# %% [markdown]
# Zdefiniujemy funkcję, która przyjmując przedział $s$, $t$ oraz wektor funkcji $v$, narysuje nam wykres oraz zwróci zbiór punktów należących do sfery.

# %%
def plot_3d(x, y, z):
    fig = plt.figure()
    ax = plt.axes(projection="3d")
    ax.plot3D(x, y, z)
    plt.show()


def draw_3d_sphere(s_range, t_range, v, n = 40):
    s = np.linspace(s_range[0], s_range[1], n)
    t = np.linspace(t_range[0], t_range[1], n)
    
    S, T = np.meshgrid(s, t)
    
    x = v[0](S, T).flatten()
    y = v[1](S, T).flatten()
    z = v[2](S, T).flatten()
    
    plot_3d(x,y,z)
    
    return x, y, z

x, y, z = draw_3d_sphere(s_range, t_range, v)

# %% [markdown]
# ***
#
# *Jak widać w wyniku dostaliśmy sferę o promieniu $R = 1$ i środku w punkcie $(0,0,0)$*

# %% [markdown]
# ---
# ### 2.
#
# Następnie wygenerujemy 3 różne macierze $A_1, A_2, A_3 (A_i \in \mathbb{R}^{3x3})$

# %%
A1 = np.random.rand(3, 3)
A2 = np.random.rand(3, 3)
A3 = np.random.rand(3, 3)

# %% [markdown]
# Za ich pomocą przekształcimy sferę w elipsoidę i przedstawimy wizualizację uzyskanego wyniku na wykresie.

# %%
S = np.row_stack([x, y, z])

E_1 = A1 @ S
E_2 = A2 @ S
E_3 = A3 @ S

plot_3d(E_1[0], E_1[1], E_1[2])
plot_3d(E_2[0], E_2[1], E_2[2])
plot_3d(E_3[0], E_3[1], E_3[2])

# %% [markdown]
# ---
# ### 3.
#
# Teraz dokonamy rozkładu wartości osobliwych SVD w każdej macierzy <strong>$A_i$</strong>.\
# Użyjemy w tym celu funkcji `linalg.svd` z biblioteki `numpy`

# %%
U1, sigma1, V1 = np.linalg.svd(A1)
U2, sigma2, V2 = np.linalg.svd(A2)
U3, sigma3, V3 = np.linalg.svd(A3)

# %% [markdown]
# Teraz na wykresie elipsoidy odpowiadającej każdej macierzy dodamy wizualizację jej półosi wyznaczonych za pomocą SVD

# %% [markdown]
# Przygotujemy zmienne na wyrysowanie półosi:

# %%
x_start, y_start, z_start = [[0] * 3] * 3
x_end = [0] * 3
y_end = [0] * 3
z_end = [0] * 3

# %% [markdown]
# ### $A_1$

# %%
for i, s1 in enumerate(np.diag(sigma1)):
    a = np.dot(U1, s1)
    x_end[i] = a[0]
    y_end[i] = a[1]
    z_end[i] = a[2]
quiver1 = [x_start, y_start, z_start, x_end, y_end, z_end]


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z)
ax.scatter(E_1[0], E_1[1], E_1[2], color='red')
ax.quiver(x_start, y_start, z_start, x_end, y_end, z_end, color='red')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)
plt.show()

# %% [markdown]
# ### $A_2$

# %%
for i, s2 in enumerate(np.diag(sigma2)):
    a = np.dot(U2, s2)
    x_end[i] = a[0]
    y_end[i] = a[1]
    z_end[i] = a[2]
quiver2 = [x_start, y_start, z_start, x_end, y_end, z_end]


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z)
ax.scatter(E_2[0], E_2[1], E_2[2], color='red')
ax.quiver(x_start, y_start, z_start, x_end, y_end, z_end, color='black')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)
plt.show()

# %% [markdown]
# ### $A_3$

# %%
for i, s3 in enumerate(np.diag(sigma3)):
    a = np.dot(U3, s3)
    x_end[i] = a[0]
    y_end[i] = a[1]
    z_end[i] = a[2]
quiver2 = [x_start, y_start, z_start, x_end, y_end, z_end]


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z)
ax.scatter(E_3[0], E_3[1], E_3[2], color='red')
ax.quiver(x_start, y_start, z_start, x_end, y_end, z_end, color='black')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)
plt.show()

# %% [markdown]
# ---
# ### 4.
# Znajdziemy taką macierz <strong>$A_i$</strong>, aby stosunek jej największej i najmniejszej wartości osobliwej był większy od 100.

# %%
A_4 = np.random.rand(3, 3)
U, sigma_4, V = np.linalg.svd(A_4)
# ponieważ wartości osobliwe są posortowane malejąco
while sigma_4[0] / sigma_4[-1] < 100:
    A_4 = np.random.rand(3, 3)
    U, sigma_4, V = np.linalg.svd(A_4)
    
A_4
# Out:
# array([[0.45375901, 0.43149745, 0.38931543],
#        [0.91610102, 0.62788049, 0.93054079],
#        [0.69540387, 0.18118636, 0.80110452]])

# %% [markdown]
# Teraz narysujemy elipsoidę dla znalezionej macierzy

# %%
E_4 = A_4 @ S
plot_3d(E_4[0], E_4[1], E_4[2])

# %% [markdown]
# ---
# ### 5.
# Dla wybranej macierzy $A_i$ mamy teraz przedstawić wizualizację $SV_i^T$, $S\Sigma_iV_i^T$ oraz $SU_i\Sigma_iV_i^T$
#
# gdzie
#
# $A_i = U_i\Sigma_iV_i^T$
# oraz
# $S$ <- sfera z punktu 1.

# %% [markdown]
# Naszą wybraną macierzą będzie $A_1$

# %%
# Make SVD
U, sigma, V = np.linalg.svd(A1)

# %% [markdown]
# $SV_i^T$

# %%
elipsoid = V.T @ S

plot_3d(elipsoid[0], elipsoid[1], elipsoid[2])

# %% [markdown]
# $S\Sigma_iV_i^T$

# %%
elipsoid = S.T * sigma @ V
elipsoid = elipsoid.T

plot_3d(elipsoid[0], elipsoid[1], elipsoid[2])

# %% [markdown]
# $SU_i\Sigma_iV_i^T$

# %%
elipsoid = S.T @ U * sigma @ V
SUSigmaV_T = elipsoid.T

plot_3d(elipsoid[0], elipsoid[1], elipsoid[2])

# %% [markdown]
# # Ex. 1) Kompresja obrazu

# %% [markdown]
# ### 1.
# Przygotujemy zdjęcie 512 x 512 pikseli

# %% [markdown]
# <img src="image.png">

# %% [markdown]
# ---
# ### 1.
# Wczytamy obraz do programu i następnie obliczymy SVD macierzy pikseli <b>$I$</b> (dla każdego koloru osobno)

# %%
matrix = np.asarray(imageio.imread('image.png'))

SVD_R = np.linalg.svd(matrix[:,:,0] , full_matrices=False)
SVD_G = np.linalg.svd(matrix[:,:,1] , full_matrices=False)
SVD_B = np.linalg.svd(matrix[:,:,2] , full_matrices=False)
compressed_image = Image.fromarray(np.uint8(matrix), "RGB")
compressed_image.save("dupa.jpg")
compressed_image.save("dupa.png")
# Out:
# [[226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  ...
#  [ 84  84  92 ... 173 172 177]
#  [ 82  82  96 ... 179 181 185]
#  [ 82  82  96 ... 179 181 185]]

# %% [markdown]
# Dla $k \in [32, 64, 96, \dots, 512]$ pierwszy wartości osobliwych dokonamy przybliżenia tej macierzy za pomocą `low rank approximation`. W ten sposób uzyskamy kompresję obrazu wyjściowego.

# %%
def low_rank_approximation(SVD, k):
    U, S, V = SVD
    Uk = np.matrix(U[:, :k])
    Sk = np.diag(S[:k])
    Vk = np.matrix(V[:k, :])
    result = Uk * Sk * Vk
    return result


def get_quality(matrix, approx_matrix):
    diff_matrix = np.subtract(matrix, approx_matrix)
    quality = np.linalg.norm(diff_matrix)
    return quality


ks = range(32, 513, 32)
qualities = []
images = []

for k in range(32, 513, 32):
    R_appr = low_rank_approximation(SVD_R, k).reshape(512*512)
    G_appr = low_rank_approximation(SVD_G, k).reshape(512*512)
    B_appr = low_rank_approximation(SVD_B, k).reshape(512*512)
    approx_matrix = np.asarray([R_appr, G_appr, B_appr]).reshape(512, 512, 3)
    print(np.uint8(approx_matrix))
    quality = get_quality(matrix, approx_matrix)
    qualities.append(quality)
    compressed_image = Image.fromarray(np.uint8(approx_matrix), "RGB")
    images.append(compressed_image)
    filename = "lenna_image_" + str(k) + ".jpg"
    compressed_image.save(filename)
# Out:
# [[[206 206 204]
#   [202 205 206]
#   [207 208 209]
#   ...
#   [196 198 198]
#   [196 195 194]
#   [193 189 183]]
#
#  [[206 206 204]
#   [202 205 206]
#   [207 208 209]
#   ...
#   [186 186 184]
#   [181 177 176]
#   [173 168 162]]
#
#  [[210 210 208]
#   [208 211 212]
#   [214 216 217]
#   ...
#   [150 146 139]
#   [131 125 119]
#   [115 109 103]]
#
#  ...
#
#  [[ 58  58  61]
#   [ 63  65  63]
#   [ 62  65  70]
#   ...
#   [ 66  63  66]
#   [ 66  69  66]
#   [ 65  64  71]]
#
#  [[ 62  62  64]
#   [ 66  66  64]
#   [ 62  63  67]
#   ...
#   [ 72  70  73]
#   [ 74  78  74]
#   [ 73  72  80]]
#
#  [[ 65  65  67]
#   [ 67  68  65]
#   [ 63  63  68]
#   ...
#   [ 72  72  75]
#   [ 76  80  79]
#   [ 78  77  83]]]
# [[[223 223 221]
#   [220 224 226]
#   [227 226 223]
#   ...
#   [200 210 219]
#   [222 222 226]
#   [221 213 198]]
#
#  [[223 223 221]
#   [220 224 226]
#   [227 226 223]
#   ...
#   [195 201 205]
#   [203 198 198]
#   [191 180 166]]
#
#  [[225 225 223]
#   [223 226 227]
#   [229 227 226]
#   ...
#   [160 153 143]
#   [131 119 111]
#   [105  99  93]]
#
#  ...
#
#  [[ 60  60  62]
#   [ 62  63  63]
#   [ 60  63  67]
#   ...
#   [ 69  64  68]
#   [ 69  73  72]
#   [ 67  70  75]]
#
#  [[ 62  62  65]
#   [ 65  64  62]
#   [ 60  61  68]
#   ...
#   [ 73  72  75]
#   [ 77  82  77]
#   [ 78  76  80]]
#
#  [[ 59  59  63]
#   [ 64  66  63]
#   [ 62  64  70]
#   ...
#   [ 79  82  81]
#   [ 82  87  79]
#   [ 81  76  79]]]
# [[[223 223 222]
#   [221 225 227]
#   [228 228 227]
#   ...
#   [200 213 223]
#   [227 227 231]
#   [227 216 197]]
#
#  [[223 223 222]
#   [221 225 227]
#   [228 228 227]
#   ...
#   [198 206 211]
#   [209 202 201]
#   [192 177 158]]
#
#  [[225 225 224]
#   [225 228 229]
#   [230 229 228]
#   ...
#   [165 154 139]
#   [124 108 101]
#   [ 95  92  87]]
#
#  ...
#
#  [[ 60  60  61]
#   [ 62  67  66]
#   [ 63  65  66]
#   ...
#   [ 70  62  67]
#   [ 69  73  73]
#   [ 67  72  79]]
#
#  [[ 60  60  62]
#   [ 61  61  62]
#   [ 58  62  70]
#   ...
#   [ 72  68  73]
#   [ 76  80  78]
#   [ 79  81  86]]
#
#  [[ 56  56  59]
#   [ 60  63  59]
#   [ 58  60  70]
#   ...
#   [ 81  86  84]
#   [ 84  90  78]
#   [ 83  76  77]]]
# [[[225 225 223]
#   [222 226 226]
#   [228 227 227]
#   ...
#   [197 212 224]
#   [229 231 235]
#   [229 218 196]]
#
#  [[225 225 223]
#   [222 226 226]
#   [228 227 227]
#   ...
#   [197 208 214]
#   [212 206 203]
#   [192 176 153]]
#
#  [[227 227 227]
#   [226 228 228]
#   [228 229 229]
#   ...
#   [168 156 139]
#   [121 106  98]
#   [ 92  90  87]]
#
#  ...
#
#  [[ 61  61  63]
#   [ 62  66  63]
#   [ 60  63  62]
#   ...
#   [ 72  60  66]
#   [ 69  75  75]
#   [ 68  74  79]]
#
#  [[ 58  58  61]
#   [ 62  64  67]
#   [ 60  64  72]
#   ...
#   [ 74  70  74]
#   [ 75  79  79]
#   [ 78  79  80]]
#
#  [[ 57  57  59]
#   [ 60  63  57]
#   [ 59  59  70]
#   ...
#   [ 80  86  83]
#   [ 83  89  77]
#   [ 83  77  79]]]
# [[[225 225 223]
#   [222 225 225]
#   [227 226 226]
#   ...
#   [196 211 224]
#   [230 231 235]
#   [230 219 197]]
#
#  [[225 225 223]
#   [222 225 225]
#   [227 226 226]
#   ...
#   [199 210 216]
#   [214 208 204]
#   [191 173 149]]
#
#  [[227 227 226]
#   [224 227 229]
#   [227 229 229]
#   ...
#   [171 159 138]
#   [119 104  97]
#   [ 90  90  89]]
#
#  ...
#
#  [[ 59  59  61]
#   [ 63  65  61]
#   [ 60  63  63]
#   ...
#   [ 74  58  62]
#   [ 68  72  74]
#   [ 68  72  77]]
#
#  [[ 57  57  58]
#   [ 60  61  64]
#   [ 60  64  71]
#   ...
#   [ 73  70  73]
#   [ 79  80  82]
#   [ 81  78  81]]
#
#  [[ 57  57  59]
#   [ 61  65  59]
#   [ 58  58  72]
#   ...
#   [ 81  88  84]
#   [ 81  88  75]
#   [ 80  80  81]]]
# [[[225 225 222]
#   [223 225 225]
#   [228 227 226]
#   ...
#   [195 210 224]
#   [229 231 235]
#   [230 219 198]]
#
#  [[225 225 222]
#   [223 225 225]
#   [228 227 226]
#   ...
#   [200 210 215]
#   [215 209 206]
#   [192 173 145]]
#
#  [[227 227 227]
#   [222 227 229]
#   [227 228 228]
#   ...
#   [174 159 137]
#   [118 103  96]
#   [ 89  91  89]]
#
#  ...
#
#  [[ 60  60  62]
#   [ 63  63  59]
#   [ 61  65  63]
#   ...
#   [ 76  59  63]
#   [ 69  72  76]
#   [ 68  71  75]]
#
#  [[ 57  57  60]
#   [ 60  62  62]
#   [ 61  65  71]
#   ...
#   [ 74  69  74]
#   [ 79  81  82]
#   [ 80  78  81]]
#
#  [[ 58  58  58]
#   [ 60  64  59]
#   [ 56  56  72]
#   ...
#   [ 81  88  84]
#   [ 81  87  75]
#   [ 81  79  80]]]
# [[[226 226 222]
#   [223 225 225]
#   [228 226 226]
#   ...
#   [195 211 224]
#   [229 231 234]
#   [230 220 199]]
#
#  [[226 226 222]
#   [223 225 225]
#   [228 226 226]
#   ...
#   [199 209 216]
#   [215 210 208]
#   [193 172 140]]
#
#  [[227 227 226]
#   [222 226 231]
#   [228 228 226]
#   ...
#   [175 161 136]
#   [118 102  95]
#   [ 89  92  90]]
#
#  ...
#
#  [[ 58  58  63]
#   [ 62  61  60]
#   [ 60  68  60]
#   ...
#   [ 77  59  63]
#   [ 68  73  77]
#   [ 66  72  76]]
#
#  [[ 57  57  62]
#   [ 60  64  64]
#   [ 60  65  73]
#   ...
#   [ 73  68  75]
#   [ 80  81  82]
#   [ 82  78  79]]
#
#  [[ 59  59  57]
#   [ 58  64  59]
#   [ 54  60  73]
#   ...
#   [ 82  90  84]
#   [ 82  88  74]
#   [ 78  79  82]]]
# [[[226 226 222]
#   [223 225 225]
#   [227 226 226]
#   ...
#   [195 211 224]
#   [229 230 234]
#   [230 220 199]]
#
#  [[226 226 222]
#   [223 225 225]
#   [227 226 226]
#   ...
#   [197 209 217]
#   [217 211 209]
#   [194 171 137]]
#
#  [[227 227 226]
#   [221 226 230]
#   [227 229 226]
#   ...
#   [177 162 136]
#   [117  99  95]
#   [ 88  93  91]]
#
#  ...
#
#  [[ 59  59  64]
#   [ 61  61  61]
#   [ 61  67  60]
#   ...
#   [ 74  58  63]
#   [ 70  73  77]
#   [ 65  70  79]]
#
#  [[ 56  56  64]
#   [ 60  63  65]
#   [ 58  66  73]
#   ...
#   [ 76  72  75]
#   [ 81  81  80]
#   [ 80  77  79]]
#
#  [[ 58  58  55]
#   [ 58  61  60]
#   [ 54  59  74]
#   ...
#   [ 82  88  84]
#   [ 80  88  75]
#   [ 79  79  81]]]
# [[[225 225 223]
#   [223 225 225]
#   [228 226 226]
#   ...
#   [195 211 223]
#   [229 230 233]
#   [230 220 200]]
#
#  [[225 225 223]
#   [223 225 225]
#   [228 226 226]
#   ...
#   [196 208 218]
#   [216 212 210]
#   [195 170 136]]
#
#  [[227 227 225]
#   [223 224 231]
#   [227 229 226]
#   ...
#   [178 162 135]
#   [117  98  96]
#   [ 89  93  91]]
#
#  ...
#
#  [[ 60  60  64]
#   [ 61  64  60]
#   [ 61  66  59]
#   ...
#   [ 74  59  62]
#   [ 70  70  78]
#   [ 64  72  80]]
#
#  [[ 55  55  65]
#   [ 60  63  64]
#   [ 58  66  75]
#   ...
#   [ 77  74  76]
#   [ 82  81  81]
#   [ 82  77  77]]
#
#  [[ 59  59  54]
#   [ 59  62  59]
#   [ 54  58  71]
#   ...
#   [ 82  88  84]
#   [ 81  89  75]
#   [ 79  79  81]]]
# [[[226 226 222]
#   [223 226 225]
#   [228 226 227]
#   ...
#   [195 211 223]
#   [228 230 233]
#   [230 220 200]]
#
#  [[226 226 222]
#   [223 226 225]
#   [228 226 227]
#   ...
#   [195 209 218]
#   [216 212 209]
#   [196 172 135]]
#
#  [[227 227 223]
#   [223 225 231]
#   [228 229 226]
#   ...
#   [177 164 135]
#   [117  96  96]
#   [ 89  93  91]]
#
#  ...
#
#  [[ 61  61  62]
#   [ 58  65  60]
#   [ 62  67  59]
#   ...
#   [ 73  58  64]
#   [ 71  70  78]
#   [ 65  71  79]]
#
#  [[ 55  55  64]
#   [ 59  63  64]
#   [ 59  66  76]
#   ...
#   [ 76  73  74]
#   [ 84  82  80]
#   [ 83  77  77]]
#
#  [[ 58  58  56]
#   [ 58  62  59]
#   [ 56  56  71]
#   ...
#   [ 82  87  85]
#   [ 80  89  75]
#   [ 79  80  80]]]
# [[[225 225 222]
#   [223 226 225]
#   [228 226 226]
#   ...
#   [196 211 223]
#   [228 230 234]
#   [230 220 200]]
#
#  [[225 225 222]
#   [223 226 225]
#   [228 226 226]
#   ...
#   [195 210 219]
#   [215 211 208]
#   [196 172 135]]
#
#  [[228 228 224]
#   [223 224 229]
#   [230 228 226]
#   ...
#   [177 165 135]
#   [117  97  96]
#   [ 89  93  92]]
#
#  ...
#
#  [[ 61  61  61]
#   [ 57  66  61]
#   [ 63  66  58]
#   ...
#   [ 74  57  63]
#   [ 71  69  76]
#   [ 67  72  79]]
#
#  [[ 56  56  65]
#   [ 58  64  61]
#   [ 60  67  76]
#   ...
#   [ 76  72  74]
#   [ 83  82  81]
#   [ 82  77  78]]
#
#  [[ 59  59  57]
#   [ 57  63  59]
#   [ 56  55  71]
#   ...
#   [ 81  87  85]
#   [ 80  89  76]
#   [ 79  80  80]]]
# [[[226 226 222]
#   [223 225 225]
#   [228 227 226]
#   ...
#   [196 211 223]
#   [228 231 233]
#   [230 220 200]]
#
#  [[226 226 222]
#   [223 225 225]
#   [228 227 226]
#   ...
#   [194 210 219]
#   [216 211 208]
#   [197 172 134]]
#
#  [[228 228 224]
#   [223 224 229]
#   [230 228 226]
#   ...
#   [177 165 135]
#   [117  97  95]
#   [ 89  93  92]]
#
#  ...
#
#  [[ 62  62  62]
#   [ 57  67  61]
#   [ 63  65  59]
#   ...
#   [ 73  58  63]
#   [ 72  69  76]
#   [ 66  72  79]]
#
#  [[ 57  57  65]
#   [ 58  63  62]
#   [ 62  65  75]
#   ...
#   [ 75  73  75]
#   [ 83  82  80]
#   [ 82  76  79]]
#
#  [[ 59  59  57]
#   [ 59  62  59]
#   [ 56  53  71]
#   ...
#   [ 82  87  85]
#   [ 80  88  76]
#   [ 78  81  81]]]
# [[[226 226 222]
#   [223 225 225]
#   [228 227 226]
#   ...
#   [196 211 223]
#   [228 230 233]
#   [230 220 200]]
#
#  [[226 226 222]
#   [223 225 225]
#   [228 227 226]
#   ...
#   [194 210 219]
#   [216 212 208]
#   [197 172 134]]
#
#  [[227 227 225]
#   [223 224 228]
#   [229 228 226]
#   ...
#   [177 165 135]
#   [117  96  96]
#   [ 88  93  92]]
#
#  ...
#
#  [[ 62  62  61]
#   [ 58  66  60]
#   [ 64  66  59]
#   ...
#   [ 72  59  62]
#   [ 72  69  76]
#   [ 65  72  79]]
#
#  [[ 56  56  64]
#   [ 59  64  62]
#   [ 62  66  75]
#   ...
#   [ 75  72  75]
#   [ 83  82  81]
#   [ 81  76  81]]
#
#  [[ 59  59  58]
#   [ 57  61  59]
#   [ 55  54  71]
#   ...
#   [ 82  87  85]
#   [ 80  88  76]
#   [ 78  81  80]]]
# [[[226 226 223]
#   [223 225 225]
#   [227 227 226]
#   ...
#   [196 211 223]
#   [228 230 234]
#   [230 220 200]]
#
#  [[226 226 223]
#   [223 225 225]
#   [227 227 226]
#   ...
#   [194 210 219]
#   [216 212 207]
#   [198 172 134]]
#
#  [[227 227 225]
#   [223 224 228]
#   [229 229 226]
#   ...
#   [178 166 134]
#   [117  97  95]
#   [ 89  93  92]]
#
#  ...
#
#  [[ 62  62  61]
#   [ 59  66  60]
#   [ 63  65  60]
#   ...
#   [ 73  59  63]
#   [ 72  69  75]
#   [ 65  71  80]]
#
#  [[ 57  57  64]
#   [ 60  63  61]
#   [ 63  66  75]
#   ...
#   [ 75  72  74]
#   [ 82  82  81]
#   [ 82  77  81]]
#
#  [[ 59  59  58]
#   [ 57  61  59]
#   [ 56  54  71]
#   ...
#   [ 82  87  85]
#   [ 80  88  76]
#   [ 79  80  80]]]
# [[[226 226 223]
#   [222 225 226]
#   [227 227 227]
#   ...
#   [195 211 224]
#   [228 230 234]
#   [230 220 200]]
#
#  [[226 226 223]
#   [222 225 226]
#   [227 227 227]
#   ...
#   [194 210 219]
#   [216 211 208]
#   [198 172 134]]
#
#  [[227 227 225]
#   [223 224 228]
#   [229 228 227]
#   ...
#   [178 166 134]
#   [117  97  95]
#   [ 88  93  92]]
#
#  ...
#
#  [[ 62  62  61]
#   [ 58  66  59]
#   [ 64  66  60]
#   ...
#   [ 72  59  63]
#   [ 73  69  75]
#   [ 65  71  80]]
#
#  [[ 57  57  64]
#   [ 59  64  61]
#   [ 64  66  75]
#   ...
#   [ 75  72  74]
#   [ 82  82  81]
#   [ 81  76  81]]
#
#  [[ 59  59  57]
#   [ 58  62  59]
#   [ 56  53  71]
#   ...
#   [ 81  87  85]
#   [ 80  88  76]
#   [ 79  80  80]]]
# [[[226 226 222]
#   [222 226 225]
#   [227 226 227]
#   ...
#   [195 210 223]
#   [228 230 233]
#   [229 220 199]]
#
#  [[226 226 222]
#   [222 226 226]
#   [228 227 226]
#   ...
#   [194 210 218]
#   [215 211 207]
#   [197 171 134]]
#
#  [[228 227 225]
#   [224 224 229]
#   [229 229 227]
#   ...
#   [177 165 134]
#   [117  96  95]
#   [ 88  93  91]]
#
#  ...
#
#  [[ 62  62  61]
#   [ 59  66  60]
#   [ 64  66  60]
#   ...
#   [ 72  58  63]
#   [ 73  70  76]
#   [ 64  71  80]]
#
#  [[ 57  56  64]
#   [ 60  63  62]
#   [ 63  66  75]
#   ...
#   [ 75  73  74]
#   [ 81  83  81]
#   [ 81  76  81]]
#
#  [[ 60  59  57]
#   [ 57  61  59]
#   [ 56  53  72]
#   ...
#   [ 81  87  85]
#   [ 80  89  76]
#   [ 78  80  81]]]

# %% [markdown]
# ---
# ### 3.
# Zaprezentujemy na wykresie jakość kompresji (oś pionowa) w zależności od liczby k (oś pozioma)

# %%
plt.plot(ks, qualities)
plt.show()

# %% [markdown]
# Teraz utworzymy plik `lennas.gif`, który zobrazuje nam, jak zmienia się obraz w zależności od liczby k

# %%
images[0].save("lennas.gif", save_all=True, append_images=images[1:], duration=256, loop=0)

# %% [markdown]
# <img src="lennas.gif" />
